# %%
# %%capture
import pandas as pd
import seaborn as sns                                                                                     
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("rocket_r")

colors = [plt.cm.tab20c(i) for i in [0, 1, 4, 5, 8]]
sns.set_palette(colors)

# %%
metrics = pd.read_csv("/Users/ochsneto/Documents/BDMM/BDMM-Flow/metrics.csv")

# %%
sns.boxplot(metrics, x="value", hue="algorithm")
plt.xscale("log")

# %%
metrics.groupby("algorithm").count()
# Out:
#            metric  time  value
# algorithm
# LP           4911  4911   4911
# Ours         4293  4293   4293

# %%
metrics[metrics.value > 1e8].groupby("algorithm").count()
# Out:
#            metric  time  value
# algorithm
# LP             15    15     15
# Ours          126   126    126

# %%
25 / 5325, 152/4620
# Out:
# (0.004694835680751174, 0.0329004329004329)

# %%
metrics.groupby("algorithm")[["time", "value"]].median()
# Out:
#                time       value
# algorithm
# LP         2.614663  198.692401
# Ours       2.927037  590.104551

# %%
2.935236	469.929973
# Out:
#   Cell In[1745], line 1
#     2.935236	469.929973
#             	^
# SyntaxError: invalid syntax
